# %% [markdown]
# <a href="https://colab.research.google.com/github/arshadhs/aiml-bits/blob/main/assignment_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignment 1 – Deep Neural Networks (DNN)

# %% [markdown]
# Programming Assignment: Comparing Linear Models and MLPs
# Course: Deep Neural Networks,
# Max Marks: 10
# Type: Individual Programming
# Submission: .ipynb + HTML version ( Download HTML version of the ipynb file)

# %% [markdown]
# # 1. Overview
# What You Will Do - Select a real-world dataset (≥ 500 samples, ≥ 10 <50 features), implement
# a baseline linear model from scratch (no sklearn models), implement an MLP from scratch,
# compare performance on test data, analyze results.
# Learning Objectives - Understand regression/classification fundamentals, implement gradient
# descent, build neural networks without high-level libraries, evaluate and compare models,
# analyze computational trade-offs.

# %% [markdown]
# #2. Dataset Requirements
#
# Source: UCI ML Repository, Kaggle, OpenML, Data.gov
# Samples: ≥ 500
# Features: ≥ 10 (excluding target)
# Data type: Numeric and/or categorical
# Task: Regression or Classification (Multiclass)
# Not Allowed Datasets- Image datasets (MNIST, CIFAR), text/NLP datasets, audio datasets,
# preprocessed datasets from Papers with Code, toy datasets with < 500 samples (Iris, Wine,
# Diabetes).

# %% [markdown]
# #Code

# %%
import numpy as np
import pandas as pd

# %%
def load_database():
  column_names = ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model_year', 'origin', 'car_name']
  #col_heart_diseases = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']
  df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data", names=column_names, sep=r"\s+", na_values='?', comment='\t')
  #df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data", names=col_heart_diseases, sep=r"\s+", na_values='?', comment='\t')
 # print (df.columns.tolist())
  #print (df.head())
  #print ("Shape:", {df.shape})
  #print ("size:", df.size)
 # print ("describe:", df.describe())
  #print ("mean:", d.mean(axis=2))
  #d = d.drop("car_name", axis='columns')

  # Drop car name (not useful for prediction)
  df = df.drop('car_name', axis=1)

  #print(df.axes)

  #print (df)

  return df

# %%
def initialise():
  return 1

# %%
def add_bias():
  return 1

# %%
def train(x, y, b, w, n):
  return 1

# %%
def predict():
    return 1

# %%
def compute_loss():
    return 1

# %%
def compute_gradient():
    return 1

# %%
def train_model():
    return 1

# %%
def main():
  df = load_database()
  x = df.drop('mpg', axis=1).to_numpy()
  print(x.shape)
  y = df['mpg'].values
  print(x.shape)
  #print (x)
  #print (y)
 # print (y
  # x = [0, 0, 1, 1]
  # y_or = [0, 1, 0, 1]

  # b = 1
  # w = 1
  # n = 0.1

  # z = train(x, y_or, b, w, n)
  # print (z)

main()
# Out:
# (398, 7)
# (398, 7)
